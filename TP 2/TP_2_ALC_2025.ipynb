# %% [markdown]
# # Segunda parte del TP de ALC 2025

# %%
# Carga de paquetes necesarios para graficar
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd # Para leer archivos
import geopandas as gpd # Para hacer cosas geográficas
import seaborn as sns # Para hacer plots lindos
import networkx as nx # Construcción de la red en NetworkX
import scipy

# %% [markdown]
# ##### Carga de funciones del Template

# %%
# Importamos las funciones del template
from template_funciones_2 import *
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_63629/1808223024.py in <cell line: 2>()
#       1 # Importamos las funciones del template
# ----> 2 from template_funciones_2 import *
#
# ~/Descargas/ALC-2025/TP 2/template_funciones_2.py in <module>
#      31     return Q
#      32
# ---> 33 def metpot1(A,tol=1e-8,maxrep=np.Inf):
#      34    # Recibe una matriz A y calcula su autovalor de mayor módulo, con un error relativo menor a tol y-o haciendo como mucho maxrep repeticiones
#      35    v = ... # Generamos un vector de partida aleatorio, entre -1 y 1
#
# NameError: name 'np' is not defined
